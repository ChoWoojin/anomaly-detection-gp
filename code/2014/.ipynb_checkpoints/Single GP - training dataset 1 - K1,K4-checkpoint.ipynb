# %%
from scipy import io
import GPy
import numpy as np
import matplotlib.pyplot as plt
import pylab as pb

# %%
def plot_2outputs(m,xlim,x_1,x_2):
    fig = pb.figure(figsize=(12,8))
    #Output 1
    ax1 = fig.add_subplot(211)
    ax1.set_xlim(xlim)
    ax1.set_ylim([4.5,6.5])
    ax1.set_title('Output 1')
    m.plot(plot_limits=xlim,fixed_inputs=[(1,0)],which_data_rows=slice(0,len(x_1)),ax=ax1, )

    #Output 2
    ax2 = fig.add_subplot(212)
    ax2.set_xlim(xlim)
    ax2.set_ylim([180,220])
    ax2.set_title('Output 2')
    m.plot(plot_limits=xlim,fixed_inputs=[(1,1)],which_data_rows=slice(len(x_1),len(x_1)+len(x_2)),ax=ax2)

# %%
def build_XY(input_list,output_list=None):
    num_outputs = len(input_list)
    Y = np.vstack(output_list)
    I = np.hstack( [np.repeat(j,_x.shape[0]) for _x,j in zip(input_list,range(num_outputs))] )
    X = np.vstack(input_list)
    X = np.hstack([X,I[:,None]])
    I = {'output_index':I[:,None]}
    return X,Y,I

# %%
mat_file1 = io.loadmat('2014_Dataset1.mat')
t = mat_file1['t']
p1 = mat_file1['p1']
p2 = mat_file1['p2']
x = np.arange(0,len(p2)/10,0.1)[:,None]

# %% [markdown]
# # Training

# %%
K1 = GPy.kern.RBF(1)
K2 = GPy.kern.Exponential(1)
K3 = GPy.kern.Matern32(1)
K4 = GPy.kern.Matern52(1)
K5 = GPy.kern.PeriodicExponential(1)
K6 = GPy.kern.PeriodicMatern32(1)
K7 = GPy.kern.PeriodicMatern52(1)

# %%
i = range(0, 10000)
j = range(0, 10000)

# %%
lcm = GPy.util.multioutput.LCM(input_dim=1,num_outputs=2,kernels_list=[K1,K4])
mul = GPy.models.SparseGPCoregionalizedRegression([x[i],x[j]],[p1[i],p2[j]],kernel=lcm,num_inducing=100)
# mul1['.*periodic_Matern32.period'].constrain_fixed(28.8)

# %%
mul.optimize()

# %%
plot_2outputs(mul,[0,1000],x[i],x[j])
plt.show()

# %%
mul
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: sparse gp<br>
# <b>Objective</b>: 10158.280521035194<br>
# <b>Number of Parameters</b>: 414<br>
# <b>Number of Optimization Parameters</b>: 214<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  sparse_gp.                           </b></th><th><b>            value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  inducing inputs                      </td><td class=tg-right>         (200, 2)</td><td class=tg-center>  {fixed}  </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM0.rbf.variance                </td><td class=tg-right>     26.750593206</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM0.rbf.lengthscale             </td><td class=tg-right>    112.578466052</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM0.B.W                         </td><td class=tg-right>           (2, 1)</td><td class=tg-center>           </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM0.B.kappa                     </td><td class=tg-right>             (2,)</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM1.Mat52.variance              </td><td class=tg-right>1.93129859971e-05</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM1.Mat52.lengthscale           </td><td class=tg-right>     2.1253085029</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM1.B.W                         </td><td class=tg-right>           (2, 1)</td><td class=tg-center>           </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM1.B.kappa                     </td><td class=tg-right>             (2,)</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  mixed_noise.Gaussian_noise_0.variance</td><td class=tg-right> 0.00469378700935</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  mixed_noise.Gaussian_noise_1.variance</td><td class=tg-right>    3.90676771776</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %%
np.hstack((np.linspace(2.5,4.,3),np.linspace(7,8.5,3)))[:,None]
# Out:
# array([[ 2.5 ],
#        [ 3.25],
#        [ 4.  ],
#        [ 7.  ],
#        [ 7.75],
#        [ 8.5 ]])

# %%
import pickle
f = open('d:/hyperparameter1_no_periodic','wb')
pickle.dump(mul,f)
f.close()

# %%
plot_2outputs(mul, xlim=(x[4500],x[9000]),x_1=x[i],x_2=x[j])
plt.show()

# %%
mul.plo
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: gp<br>
# <b>Objective</b>: -2178.1027334232153<br>
# <b>Number of Parameters</b>: 15<br>
# <b>Number of Optimization Parameters</b>: 15<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  gp.                                   </b></th><th><b>           value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  sum.ICM0.rbf.variance                 </td><td class=tg-right>   18.5185127621</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM0.rbf.lengthscale              </td><td class=tg-right>   1.90305915667</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM0.B.W                          </td><td class=tg-right>          (2, 1)</td><td class=tg-center>           </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM0.B.kappa                      </td><td class=tg-right>            (2,)</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM1.periodic_Matern52.variance   </td><td class=tg-right>  0.117264239409</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM1.periodic_Matern52.lengthscale</td><td class=tg-right>    7.1637291234</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM1.periodic_Matern52.period     </td><td class=tg-right>   5.49656360352</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM1.B.W                          </td><td class=tg-right>          (2, 1)</td><td class=tg-center>           </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM1.B.kappa                      </td><td class=tg-right>            (2,)</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  mixed_noise.Gaussian_noise_0.variance </td><td class=tg-right>0.00030970656888</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  mixed_noise.Gaussian_noise_1.variance </td><td class=tg-right>   0.68339729934</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %% [markdown]
# # Test Set

# %%
s = 0
l = 400
t = 10
it = range(s,s+l)
jt = range(s,s+l-t)
test = range(s+l-t,s+l)
kernel = mul.kern.copy()

# %%
mul2 = GPy.models.GPCoregionalizedRegression([x[it],x[jt]],[p1[it],p2[jt]],kernel = kernel)

# %%
mul2
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: gp<br>
# <b>Objective</b>: -318.97468792416413<br>
# <b>Number of Parameters</b>: 15<br>
# <b>Number of Optimization Parameters</b>: 0<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  gp.                                   </b></th><th><b>            value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  sum.ICM0.rbf.variance                 </td><td class=tg-right>    18.8496708857</td><td class=tg-center> fixed +ve </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM0.rbf.lengthscale              </td><td class=tg-right>    1.73690819959</td><td class=tg-center> fixed +ve </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM0.B.W                          </td><td class=tg-right>           (2, 1)</td><td class=tg-center>   fixed   </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM0.B.kappa                      </td><td class=tg-right>             (2,)</td><td class=tg-center> fixed +ve </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM1.periodic_Matern52.variance   </td><td class=tg-right>   0.833650651036</td><td class=tg-center> fixed +ve </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM1.periodic_Matern52.lengthscale</td><td class=tg-right>    1.18805153455</td><td class=tg-center> fixed +ve </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM1.periodic_Matern52.period     </td><td class=tg-right>    5.99948056739</td><td class=tg-center> fixed +ve </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM1.B.W                          </td><td class=tg-right>           (2, 1)</td><td class=tg-center>   fixed   </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM1.B.kappa                      </td><td class=tg-right>             (2,)</td><td class=tg-center> fixed +ve </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  mixed_noise.Gaussian_noise_0.variance </td><td class=tg-right>0.000269188706549</td><td class=tg-center> fixed +ve </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  mixed_noise.Gaussian_noise_1.variance </td><td class=tg-right>   0.643911697066</td><td class=tg-center> fixed +ve </td><td class=tg-center>      </td></tr>
# </table>

# %%
# mul2['.*rbf.variance'].constrain_fixed(mul.sum.ICM0.rbf.variance)
# mul2['.*rbf.lengthscale'].constrain_fixed(mul.sum.ICM0.rbf.lengthscale)
# mul2['.*periodic_Matern52.variance'].constrain_fixed(mul.sum.ICM1.periodic_Matern52.variance)
# mul2['.*periodic_Matern52.lengthscale'].constrain_fixed(mul.sum.ICM1.periodic_Matern52.lengthscale)
# mul2['.*periodic_Matern52.period'].constrain_fixed(mul.sum.ICM1.periodic_Matern52.period)
mul2['.*Gaussian_noise_0.variance'].constrain_fixed(mul.mixed_noise.Gaussian_noise_0.variance)
mul2['.*Gaussian_noise_1.variance'].constrain_fixed(mul.mixed_noise.Gaussian_noise_1.variance)
# mul2['.*ICM0.B.W'].constrain_fixed(mul.sum.ICM0.B.W)
# mul2['.*ICM1.B.W'].constrain_fixed(mul.sum.ICM1.B.W)
# mul2['.*ICM0.B.kappa'].constrain_fixed(mul.sum.ICM0.B.kappa)
# mul2['.*ICM1.B.kappa'].constrain_fixed(mul.sum.ICM1.B.kappa)
# Out:
# array([0])

# %%
mul2
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: gp<br>
# <b>Objective</b>: -318.97468792416413<br>
# <b>Number of Parameters</b>: 15<br>
# <b>Number of Optimization Parameters</b>: 0<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  gp.                                   </b></th><th><b>            value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  sum.ICM0.rbf.variance                 </td><td class=tg-right>    18.8496708857</td><td class=tg-center> fixed +ve </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM0.rbf.lengthscale              </td><td class=tg-right>    1.73690819959</td><td class=tg-center> fixed +ve </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM0.B.W                          </td><td class=tg-right>           (2, 1)</td><td class=tg-center>   fixed   </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM0.B.kappa                      </td><td class=tg-right>             (2,)</td><td class=tg-center> fixed +ve </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM1.periodic_Matern52.variance   </td><td class=tg-right>   0.833650651036</td><td class=tg-center> fixed +ve </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM1.periodic_Matern52.lengthscale</td><td class=tg-right>    1.18805153455</td><td class=tg-center> fixed +ve </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM1.periodic_Matern52.period     </td><td class=tg-right>    5.99948056739</td><td class=tg-center> fixed +ve </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM1.B.W                          </td><td class=tg-right>           (2, 1)</td><td class=tg-center>   fixed   </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM1.B.kappa                      </td><td class=tg-right>             (2,)</td><td class=tg-center> fixed +ve </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  mixed_noise.Gaussian_noise_0.variance </td><td class=tg-right>0.000269188706549</td><td class=tg-center> fixed +ve </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  mixed_noise.Gaussian_noise_1.variance </td><td class=tg-right>   0.643911697066</td><td class=tg-center> fixed +ve </td><td class=tg-center>      </td></tr>
# </table>

# %%
plot_2outputs(mul2, xlim=(x[s],x[s+l]),x_1=x[it],x_2=x[jt])
plt.show()

# %%
plot_2outputs(mul2, xlim=(x[s+l-1*t],x[s+l]),x_1=x[it],x_2=x[jt])
plt.plot(x[test],p2[test],'kx',color='red')
plt.show()

# %% [markdown]
# # Anomaly Score

# %%
X,Y,I = build_XY([x[it],x[it]],[p1[it],p2[it]])
mu,var = mul2.predict(X,Y_metadata=I,kern=mul2.kern,likelihood=mul2.likelihood)
mu2 = mu[int(len(mu)/2):len(mu)]
var2 = var[int(len(mu)/2):len(mu)]

# %%
score = 0.5*np.log(var2[test]*np.pi*2) + (p2[test]-mu2[test])**2/(2*var2[test])
np.average(score)
# Out:
# 2.0743724729091233

# %% [markdown]
# # Sequential

# %%
def hyper_fix_score(kernel,mul2,s,l,t):
    it = range(s,s+l)
    jt = range(s,s+l-t)
    test = range(l-t,l)    
    mul2 = GPy.models.GPCoregionalizedRegression([x[it],x[jt]],[p1[it],p2[jt]],kernel = kernel)
    mul2['.*Gaussian_noise_0.variance'].constrain_fixed(mul.mixed_noise.Gaussian_noise_0.variance)
    mul2['.*Gaussian_noise_1.variance'].constrain_fixed(mul.mixed_noise.Gaussian_noise_1.variance)
    X,Y,I = build_XY([x[it],x[it]],[p1[it],p2[it]])
    mu,var = mul2.predict(X,Y_metadata=I,kern=mul2.kern,likelihood=mul2.likelihood)
    mu2 = mu[int(len(mu)/2):len(mu)]
    var2 = var[int(len(mu)/2):len(mu)]
    score = 0.5*np.log(var2[test]*np.pi*2) + (p2[test]-mu2[test])**2/(2*var2[test])
    a = np.average(score)
    return a

# %%
s = 0
l = 400
t = 10
score_list = []
kern = mul.kern.copy()
for i in range(len(x)):
    a = hyper_fix_score(kern,mul2,s,l,t)
    score_list.append(a)
    s += 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-42-08ec75e115d3> in <module>()
#       5 kern = mul.kern.copy()
#       6 for i in range(len(x)):
# ----> 7     a = hyper_fix_score(kern,mul2,s,l,t)
#       8     score_list.append(a)
#       9     s += 1
#
# <ipython-input-40-601d121aada9> in hyper_fix_score(kernel, mul2, s, l, t)
#       3     jt = range(s,s+l-t)
#       4     test = range(l-t,l)
# ----> 5     mul2 = GPy.models.GPCoregionalizedRegression([x[it],x[jt]],[p1[it],p2[jt]],kernel = kernel)
#       6     mul2['.*Gaussian_noise_0.variance'].constrain_fixed(mul.mixed_noise.Gaussian_noise_0.variance)
#       7     mul2['.*Gaussian_noise_1.variance'].constrain_fixed(mul.mixed_noise.Gaussian_noise_1.variance)
#
# IndexError: index 17250 is out of bounds for axis 0 with size 17250

# %%
plt.figure(figsize=(20,10))
plt.plot(score_list)
plt.show()

# %%
if 0.1:
    print(1)
# Out:
# 1
