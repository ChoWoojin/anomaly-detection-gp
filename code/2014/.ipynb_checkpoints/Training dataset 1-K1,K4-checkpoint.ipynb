# %%
from scipy import io
import GPy
import numpy as np
import matplotlib.pyplot as plt
import pylab as pb
import GPy.inference.latent_function_inference.exact_gaussian_inference as eg

np.random.seed(2017)

# %%
def plot_2outputs(m,xlim,x_1,x_2):
    fig = pb.figure(figsize=(12,8))
    #Output 1
    ax1 = fig.add_subplot(211)
    ax1.set_xlim(xlim)
    ax1.set_title('Output 1')
    m.plot(plot_limits=xlim,fixed_inputs=[(1,0)],which_data_rows=slice(0,len(x_1)),ax=ax1)

    #Output 2
    ax2 = fig.add_subplot(212)
    ax2.set_xlim(xlim)
    ax2.set_title('Output 2')
    m.plot(plot_limits=xlim,fixed_inputs=[(1,1)],which_data_rows=slice(len(x_1),len(x_1)+len(x_2)),ax=ax2)

# %%
def build_XY(input_list,output_list=None):
    num_outputs = len(input_list)
    Y = np.vstack(output_list)
    I = np.hstack( [np.repeat(j,_x.shape[0]) for _x,j in zip(input_list,range(num_outputs))] )
    X = np.vstack(input_list)
    X = np.hstack([X,I[:,None]])
    I = {'output_index':I[:,None]}
    return X,Y,I

# %%
mat_file1 = io.loadmat('2014_Dataset1.mat')
t = mat_file1['t']
p1 = mat_file1['p1']
p2 = mat_file1['p2']
plt.plot(t,p2)
plt.show()

# %%
x = np.arange(0,len(p2)/10,0.1)[:,None]
plt.plot(x,p2)
plt.show()

# %% [markdown]
# # Training

# %%
K1 = GPy.kern.RBF(1)
K2 = GPy.kern.Exponential(1)
K3 = GPy.kern.Matern32(1)
K4 = GPy.kern.Matern52(1)
K5 = GPy.kern.PeriodicExponential(1)
K6 = GPy.kern.PeriodicMatern32(1)
K7 = GPy.kern.PeriodicMatern52(1)
K8 = GPy.kern.RBF(1)

# %%
i = slice(0, 5000)
j = slice(0, 5000)

# %%
lcm = GPy.util.multioutput.LCM(input_dim=1,num_outputs=2,kernels_list=[K2,K4,K5])
mul = GPy.models.GPCoregionalizedRegression([x[i],x[j]],[p1[i],p2[j]],kernel = lcm)
# mul1['.*periodic_Matern32.period'].constrain_fixed(28.8)
mul.optimize()

# %%
plot_2outputs(mul, xlim=(x[3000],x[3200-1]),x_1=x[i],x_2=x[j])
plt.show()

# %%
mul
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: gp<br>
# <b>Objective</b>: -6063.836008847601<br>
# <b>Number of Parameters</b>: 21<br>
# <b>Number of Optimization Parameters</b>: 21<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  gp.                                      </b></th><th><b>            value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  sum.ICM0.Exponential.variance            </td><td class=tg-right>0.000681553504849</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM0.Exponential.lengthscale         </td><td class=tg-right>    45.6982359908</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM0.B.W                             </td><td class=tg-right>           (2, 1)</td><td class=tg-center>           </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM0.B.kappa                         </td><td class=tg-right>             (2,)</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM1.Mat52.variance                  </td><td class=tg-right>    53.7449237248</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM1.Mat52.lengthscale               </td><td class=tg-right>    48.6298903667</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM1.B.W                             </td><td class=tg-right>           (2, 1)</td><td class=tg-center>           </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM1.B.kappa                         </td><td class=tg-right>             (2,)</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM2.periodic_exponential.variance   </td><td class=tg-right>0.000139768998473</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM2.periodic_exponential.lengthscale</td><td class=tg-right>    17.4730777075</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM2.periodic_exponential.period     </td><td class=tg-right>    5.61635716336</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM2.B.W                             </td><td class=tg-right>           (2, 1)</td><td class=tg-center>           </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM2.B.kappa                         </td><td class=tg-right>             (2,)</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  mixed_noise.Gaussian_noise_0.variance    </td><td class=tg-right>1.37062915368e-35</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  mixed_noise.Gaussian_noise_1.variance    </td><td class=tg-right>   0.676744320416</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %% [markdown]
# # Test Set
