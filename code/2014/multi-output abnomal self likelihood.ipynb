# %%
from scipy import io
import GPy
import numpy as np
import matplotlib.pyplot as plt
import pylab as pb
import GPy.inference.latent_function_inference.exact_gaussian_inference as eg

# %%
mat_file = io.loadmat('2015_Dataset4.mat')
t = mat_file['t']
p1 = mat_file['p1']
p2 = mat_file['p2']
t = t*24

# %%
le = 288*5
x_1 = np.arange(0,le/10,0.1)
x_1 = np.reshape(x_1,[len(x_1),1])
print(len(x_1))
start = 8646-288*2
p1_1 = p1[start:start+le]
p2_1 = p2[start:start+le]
y_1 = p1_1
y_2 = p2_1
print(len(y_1))
# Out:
# 1440
# 1440

# %%
plt.plot(x_1,y_2)
plt.show()

# %%
def plot_2outputs(m,xlim):
    fig = pb.figure(figsize=(12,8))
    #Output 1
    ax1 = fig.add_subplot(211)
    ax1.set_xlim(xlim)
    ax1.set_title('Output 1')
    m.plot(plot_limits=xlim,fixed_inputs=[(1,0)],which_data_rows=slice(0,len(x_1)),ax=ax1)

    #Output 2
    ax2 = fig.add_subplot(212)
    ax2.set_xlim(xlim)
    ax2.set_title('Output 2')
    m.plot(plot_limits=xlim,fixed_inputs=[(1,1)],which_data_rows=slice(len(x_1),len(x_1)+len(x_1)),ax=ax2)

# %%
K1 = GPy.kern.RBF(1)
K2 = GPy.kern.PeriodicMatern52(1, period = 28.8)
lcm = GPy.util.multioutput.LCM(input_dim=1,num_outputs=2,kernels_list=[K1,K2])

# %%
mul = GPy.models.GPCoregionalizedRegression([x_1,x_1],[y_1,y_2],kernel = lcm)
mul['.*periodic_Matern52.period'].constrain_fixed(28.8)
mul.optimize()
plot_2outputs(mul, xlim=(0,x_1[len(x_1)-1]))
plt.show()

# %%
mul
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: gp<br>
# <b>Objective</b>: -7863.115378181388<br>
# <b>Number of Parameters</b>: 15<br>
# <b>Number of Optimization Parameters</b>: 14<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  gp.                                   </b></th><th><b>            value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  sum.ICM0.rbf.variance                 </td><td class=tg-right>  0.0433168828693</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM0.rbf.lengthscale              </td><td class=tg-right>    2.47732042448</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM0.B.W                          </td><td class=tg-right>           (2, 1)</td><td class=tg-center>           </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM0.B.kappa                      </td><td class=tg-right>             (2,)</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM1.periodic_Matern52.variance   </td><td class=tg-right>1.26598097215e-21</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM1.periodic_Matern52.lengthscale</td><td class=tg-right>    182.785857949</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM1.periodic_Matern52.period     </td><td class=tg-right>             28.8</td><td class=tg-center> fixed +ve </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM1.B.W                          </td><td class=tg-right>           (2, 1)</td><td class=tg-center>           </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.ICM1.B.kappa                      </td><td class=tg-right>             (2,)</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  mixed_noise.Gaussian_noise_0.variance </td><td class=tg-right>7.52224990445e-06</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  mixed_noise.Gaussian_noise_1.variance </td><td class=tg-right> 0.00352387165993</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %%
def build_XY(input_list,output_list=None):
    num_outputs = len(input_list)
    Y = np.vstack(output_list)
    I = np.hstack( [np.repeat(j,_x.shape[0]) for _x,j in zip(input_list,range(num_outputs))] )
    X = np.vstack(input_list)
    X = np.hstack([X,I[:,None]])
    I = {'output_index':I[:,None]}
    return X,Y,I

# %%
lkd = np.zeros(len(x_1))
for i in range(len(x_1)):
    xi = [x_1[i:i+24],x_1[i:i+24]]
    yi = [y_1[i:i+24],y_2[i:i+24]]
    Xi, Yi, Ii = build_XY(xi, yi)
    p, lkd[i], grad = eg.ExactGaussianInference.inference(mul, mul.kern, Xi, mul.likelihood, Yi, Y_metadata = Ii)

# %%
plt.plot(x_1, lkd)
plt.show()

# %%
y_1.size
# Out:
# 1440
